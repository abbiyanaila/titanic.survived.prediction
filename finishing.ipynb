# %%
import pandas as pd
import numpy as np
df = pd.read_csv('test.csv')

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df.shape
# Out:
# (418, 11)

# %%
df_test = df.drop(['Name', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], axis=1)
df_test
# Out:
#      PassengerId  Pclass     Sex   Age
# 0            892       3    male  34.5
# 1            893       3  female  47.0
# 2            894       2    male  62.0
# 3            895       3    male  27.0
# 4            896       3  female  22.0
# 5            897       3    male  14.0
# 6            898       3  female  30.0
# 7            899       2    male  26.0
# 8            900       3  female  18.0
# 9            901       3    male  21.0
# 10           902       3    male   NaN
# 11           903       1    male  46.0
# 12           904       1  female  23.0
# 13           905       2    male  63.0
# 14           906       1  female  47.0
# 15           907       2  female  24.0
# 16           908       2    male  35.0
# 17           909       3    male  21.0
# 18           910       3  female  27.0
# 19           911       3  female  45.0
# 20           912       1    male  55.0
# 21           913       3    male   9.0
# 22           914       1  female   NaN
# ...

# %%
mapping = {'female': 0, 'male': 1}
df_test = df_test.replace({'Sex': mapping})

# %%
df_test.head()
# Out:
#    PassengerId  Pclass  Sex   Age
# 0          892       3    1  34.5
# 1          893       3    0  47.0
# 2          894       2    1  62.0
# 3          895       3    1  27.0
# 4          896       3    0  22.0

# %%
df_test.fillna(0, inplace=True)

# %%
from joblib import dump, load

# %%
def predict_survivor(pclass, sex, age):
    ''' sex = 0 is female, 1 is male '''
    test = np.array([[ sex, pclass, age]])
    rf_clf = load('titanic.joblib') 
    pred = rf_clf.predict(test)
    return pred[0]

# %%
sex = 1
age = 34.5
pclass = 3
test = np.array([[ sex, pclass, age]])
test
# Out:
# array([[  1. ,   3. ,  34.5]])

# %%
_, pcs, sex, age = df_test.iloc[0].values
predict_survivor(pcs, sex, age)
# Out:
# 1

# %%
df_test["Survived"] = ""

# %%
test = df_test[['Pclass','Sex', 'Age']].values
type(test)
# rf_clf = load('titanic.joblib') 
# pred = rf_clf.predict(test)
# df_test['Survived'] = pred
# Out:
# numpy.ndarray

# %%
a = df_test[[ 'Sex', 'Pclass', 'Age']].values
rf_clf = load('titanic.joblib') 
pred = rf_clf.predict(a)
df_test['Survived'] = pred

# %%
df_test.head()
# Out:
#    PassengerId  Pclass  Sex   Age  Survived
# 0          892       3    1  34.5         1
# 1          893       3    0  47.0         0
# 2          894       2    1  62.0         0
# 3          895       3    1  27.0         1
# 4          896       3    0  22.0         0

# %%
df_test.shape
# Out:
# (418, 5)

# %%
drop = df_test.drop(['Pclass', 'Sex', 'Age'], axis=1)
drop.head()
# Out:
#    PassengerId  Survived
# 0          892         1
# 1          893         0
# 2          894         0
# 3          895         1
# 4          896         0

# %%
filename = 'gender_submission.csv'
drop.to_csv(filename, index=False)

# %%
df_test.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Sex              int64
# Age            float64
# Survived         int64
# dtype: object

# %%
a = np.array([1,2,3])
a.shape
# Out:
# (3,)

# %%
b = np.array([[1,2,3]])
b.shape
# Out:
# (1, 3)
